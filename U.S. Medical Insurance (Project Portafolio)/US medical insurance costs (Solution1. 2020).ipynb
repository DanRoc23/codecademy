# %% [markdown]
# # U.S. Medical Insurance Costs

# %% [markdown]
# Sábado 17 de abril, 2020

# %% [markdown]
# 1. First, I imported random, Decimal, csv, Counter and operator.
# 2. Second, I opened the csv document and stored the information in a new list

# %%
import random
from decimal import Decimal
import csv
from collections import Counter
import operator


insured = []
with open("insurance.csv", newline="") as insurance_csv:
    insurance_reader = csv.DictReader(insurance_csv)
    for row in insurance_reader:
        insured.append(row)

# %% [markdown]
# I stored the information in a class with the following methods:
#
# 1. `__init__´ to declare the class attributes, in this case the attributes are equivalent to the "insured" list
# 2. `__repr__´ to represent as str.
#
# The next two functions are actually quirks of the programmer:
#
# 3. Suppose we want to check later the record of a random insured, we will need his number his id (the number of index within the list of insured), the first function returns a random number within the index.
# 4. The second function is in case we want to add a new record, it returns an extra number of index, that will be the id_number of the new record.
# 5. To find out the average age of the patients in the dataset.
# 6. To Analyze where a majority of the individuals are from.
# 7. To analyze the most common sex.
# 8. To analyze the most common smoker status.
# 9. Look at the different costs between smokers vs. non-smokers.
# 10. Figure out what the average age is for someone who has at least one child in this dataset.

# %%
class Insured_people:
    def __init__(self):
        self.new_insured = insured
    def __repr__(self):
        return new_insured
    def insurance_id_info (self):
        new_insured = self.new_insured
        insured_indexes = list(range(int(len(new_insured))))
        random_number = random.choice(insured_indexes)
        return random_number
    def insurance_new_record(self):
        return len(insured)
    def get_average(self):
        sum = 0
        for row in self.new_insured:
            age = float(row["age"])
            sum += age
        return int(sum /len(insured))
    def majority_zone(self):
        insured_zones = Counter(row["region"] for row in insured if row.get("region"))
        for region, count in insured_zones.most_common():
            return region
    def majority_sex(self):
        f_or_m = Counter(row["sex"] for row in insured if row.get("sex"))
        for sex, count in f_or_m.most_common():
            if sex == "male" or sex == 1:
                return "Males"
            else:
                return "Females"
    def majority_smoker(self):
        smoker_or_nonsmoker = Counter(row["smoker"] for row in insured if row.get("smoker") == "yes" or row.get("smoker") == "no" or row.get("smoker") == 1 or row.get("smoker") == 0)
        for status, count in smoker_or_nonsmoker.most_common():
            if status == "no" or status == 0:
                return "Non-Smokers"
            else:
                return "Smokers"
    def costs_smoker_status(self, status):
        smokers_costs = [row["charges"] for row in self.new_insured if row.get("smoker") == "yes" or row.get("smoker") == 1 ]
        non_smokers_costs = [row["charges"] for row in self.new_insured if row.get("smoker") == "no" or row.get("smoker") == 0]
        if status == 1:
            return smokers_costs
        elif status == 0:
            return non_smokers_costs
        if isinstance(status, str):
            return "You must register the status using floats. 0 for Non-Smokers or 1 for Smokers."
        else:
            return "You must register 0 for Non-Smokers or 1 for Smokers"
    def age_average_per_child(self):
        ages_per_child = [row["age"] for row in self.new_insured if float(row["children"]) != 0]
        sum = 0
        for age in ages_per_child:
            sum += int(age)
        return int(sum/len(ages_per_child))

# %% [markdown]
# I printed several tests of the methods

# %%
insured_people = Insured_people()
print(insured_people.new_insured[0])
print(insured_people.new_insured[1])
print(insured_people.get_average())
print(insured_people.majority_zone())
print(insured_people.majority_sex())
print(insured_people.majority_smoker())
print(insured_people.costs_smoker_status(0))
print(insured_people.costs_smoker_status(1))
print(insured_people.costs_smoker_status("h"))
print(insured_people.costs_smoker_status(4))
print(insured_people.age_average_per_child())
# Out:
# {'age': '19', 'sex': 'female', 'bmi': '27.9', 'children': '0', 'smoker': 'yes', 'region': 'southwest', 'charges': '16884.924'}
# {'age': '18', 'sex': 'male', 'bmi': '33.77', 'children': '1', 'smoker': 'no', 'region': 'southeast', 'charges': '1725.5523'}
# 39
# southeast
# Males
# Non-Smokers
# ['1725.5523', '4449.462', '21984.47061', '3866.8552', '3756.6216', '8240.5896', '7281.5056', '6406.4107', '28923.13692', '2721.3208', '1826.843', '11090.7178', '1837.237', '10797.3362', '2395.17155', '10602.385', '13228.84695', '4149.736', '1137.011', '6203.90175', '14001.1338', '14451.83515', '12268.63225', '2775.19215', '2198.18985', '4687.797', '13770.0979', '1625.43375', '15612.19335', '2302.3', '3046.062', '4949.7587', '6272.4772', '6313.759', '6079.6715', '20630.28351', '3393.35635', '3556.9223', '12629.8967', '2211.13075', '3579.8287', '8059.6791', '13607.36875', '5989.52365', '8606.2174', '4504.6624', '30166.61817', '4133.64165', '1743.214', '14235.072', '6389.37785', '5920.1041', '6799.458', '11741.726', '11946.6259', '7726.854', '11356.6609', '3947.4131', '1532.4697', '2755.02095', '6571.02435', '4441.21315', '7935.29115', '11033.6617', '11073.176', '8026.6666', '11082.5772', '2026.9741', '10942.13205', '5729.0053', '3766.8838', '12105.32', '10226.2842', '6186.127', '3645.0894', '21344.8467', '5003.853', '2331.519', '3877.30425', '2867.1196', '10825.2537', '11881.358', '4646.759', '2404.7338', '11488.31695', '30259.99556', '11381.3254', '8601.3293', '6686.4313', '7740.337', '1705.6245', '2257.47525', '10115.00885', '3385.39915', '9634.538', '6082.405', '12815.44495', '13616.3586', '11163.568', '1632.56445', '2457.21115', '2155.6815', '1261.442', '2045.68525', '27322.73386', '2166.732', '27375.90478', '3490.5491', '18157.876', '5138.2567', '9877.6077', '10959.6947', '1842.519', '5125.2157', '7789.635', '6334.34355', '7077.1894', '6948.7008', '19749.38338', '10450.552', '5152.134', '5028.1466', '10407.08585', '4830.63', '6128.79745', '2719.27975', '4827.90495', '13405.3903', '8116.68', '1694.7964', '5246.047', '2855.43755', '6455.86265', '10436.096', '8823.279', '8538.28845', '11735.87905', '1631.8212', '4005.4225', '7419.4779', '7731.4271', '3981.9768', '5325.651', '6775.961', '4922.9159', '12557.6053', '4883.866', '2137.6536', '12044.342', '1137.4697', '1639.5631', '5649.715', '8516.829', '9644.2525', '14901.5167', '2130.6759', '8871.1517', '13012.20865', '7147.105', '4337.7352', '11743.299', '13880.949', '6610.1097', '1980.07', '8162.71625', '3537.703', '5002.7827', '8520.026', '7371.772', '10355.641', '2483.736', '3392.9768', '25081.76784', '5012.471', '10564.8845', '5253.524', '11987.1682', '2689.4954', '24227.33724', '7358.17565', '9225.2564', '7443.64305', '14001.2867', '1727.785', '12333.828', '6710.1919', '1615.7667', '4463.2051', '7152.6714', '5354.07465', '35160.13457', '7196.867', '24476.47851', '12648.7034', '1986.9334', '1832.094', '4040.55825', '4260.744', '13047.33235', '5400.9805', '11520.09985', '11837.16', '20462.99766', '14590.63205', '7441.053', '9282.4806', '1719.4363', '7265.7025', '9617.66245', '2523.1695', '9715.841', '2803.69785', '2150.469', '12928.7911', '9855.1314', '4237.12655', '11879.10405', '9625.92', '7742.1098', '9432.9253', '14256.1928', '25992.82104', '3172.018', '20277.80751', '2156.7518', '3906.127', '1704.5681', '9249.4952', '6746.7425', '12265.5069', '4349.462', '12646.207', '19442.3535', '20177.67113', '4151.0287', '11944.59435', '7749.1564', '8444.474', '1737.376', '8124.4084', '9722.7695', '8835.26495', '10435.06525', '7421.19455', '4667.60765', '4894.7533', '24671.66334', '11566.30055', '2866.091', '6600.20595', '3561.8889', '9144.565', '13429.0354', '11658.37915', '19144.57652', '13822.803', '12142.5786', '13937.6665', '8232.6388', '18955.22017', '13352.0998', '13217.0945', '13981.85035', '10977.2063', '6184.2994', '4889.9995', '8334.45755', '5478.0368', '1635.73365', '11830.6072', '8932.084', '3554.203', '12404.8791', '14133.03775', '24603.04837', '8944.1151', '9620.3307', '1837.2819', '1607.5101', '10043.249', '4751.07', '2597.779', '3180.5101', '9778.3472', '13430.265', '8017.06115', '8116.26885', '3481.868', '13415.0381', '12029.2867', '7639.41745', '1391.5287', '16455.70785', '27000.98473', '20781.48892', '5846.9176', '8302.53565', '1261.859', '11856.4115', '30284.6429 ...
# ['16884.924', '27808.7251', '39611.7577', '36837.467', '37701.8768', '38711', '35585.576', '51194.55914', '39774.2763', '48173.361', '38709.176', '23568.272', '37742.5757', '47496.49445', '34303.1672', '23244.7902', '14711.7438', '17663.1442', '16577.7795', '37165.1638', '39836.519', '21098.55405', '43578.9394', '30184.9367', '47291.055', '22412.6485', '15820.699', '30942.1918', '17560.37975', '47055.5321', '19107.7796', '39556.4945', '17081.08', '32734.1863', '18972.495', '20745.9891', '40720.55105', '19964.7463', '21223.6758', '15518.18025', '36950.2567', '21348.706', '36149.4835', '48824.45', '43753.33705', '37133.8982', '20984.0936', '34779.615', '19515.5416', '19444.2658', '17352.6803', '38511.6283', '29523.1656', '12829.4551', '47305.305', '44260.7499', '41097.16175', '43921.1837', '33750.2918', '17085.2676', '24869.8368', '36219.40545', '46151.1245', '17179.522', '42856.838', '22331.5668', '48549.17835', '47896.79135', '42112.2356', '16297.846', '21978.6769', '38746.3551', '24873.3849', '42124.5153', '34838.873', '35491.64', '42760.5022', '47928.03', '48517.56315', '24393.6224', '41919.097', '13844.506', '36085.219', '18033.9679', '21659.9301', '38126.2465', '15006.57945', '42303.69215', '19594.80965', '14455.64405', '18608.262', '28950.4692', '46889.2612', '46599.1084', '39125.33225', '37079.372', '26109.32905', '22144.032', '19521.9682', '25382.297', '28868.6639', '35147.52848', '48885.13561', '17942.106', '36197.699', '22218.1149', '32548.3405', '21082.16', '38245.59327', '48675.5177', '63770.42801', '23807.2406', '45863.205', '39983.42595', '45702.02235', '58571.07448', '43943.8761', '15359.1045', '17468.9839', '25678.77845', '39241.442', '42969.8527', '23306.547', '34439.8559', '40182.246', '34617.84065', '42983.4585', '20149.3229', '32787.45859', '24667.419', '27037.9141', '42560.4304', '40003.33225', '45710.20785', '46200.9851', '46130.5265', '40103.89', '34806.4677', '40273.6455', '44400.4064', '40932.4295', '16657.71745', '19361.9988', '40419.0191', '36189.1017', '44585.45587', '18246.4955', '43254.41795', '19539.243', '23065.4207', '36307.7983', '19040.876', '17748.5062', '18259.216', '24520.264', '21195.818', '18310.742', '17904.52705', '38792.6856', '23401.30575', '55135.40209', '43813.8661', '20773.62775', '39597.4072', '36021.0112', '27533.9129', '45008.9555', '37270.1512', '42111.6647', '24106.91255', '40974.1649', '15817.9857', '46113.511', '46255.1125', '19719.6947', '27218.43725', '29330.98315', '44202.6536', '19798.05455', '48673.5588', '17496.306', '33732.6867', '21774.32215', '35069.37452', '39047.285', '19933.458', '47462.894', '38998.546', '20009.63365', '41999.52', '41034.2214', '23967.38305', '16138.76205', '19199.944', '14571.8908', '16420.49455', '17361.7661', '34472.841', '24915.22085', '18767.7377', '35595.5898', '42211.1382', '16450.8947', '21677.28345', '44423.803', '13747.87235', '37484.4493', '39725.51805', '20234.85475', '33475.81715', '21880.82', '44501.3982', '39727.614', '25309.489', '48970.2476', '39871.7043', '34672.1472', '19023.26', '41676.0811', '33907.548', '44641.1974', '16776.30405', '41949.2441', '24180.9335', '36124.5737', '38282.7495', '34166.273', '46661.4424', '40904.1995', '36898.73308', '52590.82939', '40941.2854', '39722.7462', '17178.6824', '22478.6', '23887.6627', '19350.3689', '18328.2381', '37465.34375', '21771.3423', '33307.5508', '18223.4512', '38415.474', '20296.86345', '41661.602', '26125.67477', '60021.39897', '20167.33603', '47269.854', '49577.6624', '37607.5277', '18648.4217', '16232.847', '26926.5144', '34254.05335', '17043.3414', '22462.04375', '24535.69855', '14283.4594', '47403.88', '38344.566', '34828.654', '62592.87309', '46718.16325', '37829.7242', '21259.37795', '16115.3045', '21472.4788', '33900.653', '36397.576', '18765.87545', '28101.33305', '43896.3763', '29141.3603']
# You must register the status using floats. 0 for Non-Smokers or 1 for Smokers.
# You must register 0 for Non-Smokers or 1 for Smokers
# 39

# %% [markdown]
# I create a subclass to acces the information of an individual and return it. (This also can be done with indexes, as the `print(insured_people.new_insured[1])´ does.

# %%
class Insured_Person(Insured_people):
    def __init__(self, id_number):
        id_number = insured[id_number]
        self.index = id_number
        self.age = self.index["age"]
        self.sex = self.index["sex"]
        self.bmi = self.index["bmi"]
        self.children = self.index ["children"]
        self.smoker = self.index["smoker"]
        self.region = self.index["region"]
        self.charges = self.index ["charges"]
    def insured_info(self):
        return self.index

# %%
maurice = Insured_Person(1)
print(maurice.insured_info())
print(maurice.charges)
# Out:
# {'age': '18', 'sex': 'male', 'bmi': '33.77', 'children': '1', 'smoker': 'no', 'region': 'southeast', 'charges': '1725.5523'}
# 1725.5523

# %% [markdown]
# I create a subclass to access to estimated the differences beetween the estimated cost and the real cost.

# %%
class Estimated_Insurances_Costs(Insured_people):
    def estimated_difference(self):
        insured_updated = []
        estimated_costs = []
        real_vs_estimated = []
        differences = []
        for row in insured:
            if row["sex"] == "male" and row["smoker"] == "no":
                row["sex"] = 0
                row["smoker"] = 0 
            elif row["sex"] == "female" and row["smoker"] == "yes":
                row["sex"] = 1
                row["smoker"] = 1
            elif row["sex"] == "male" and row["smoker"] == "yes":
                row["sex"] = 0
                row["smoker"] = 1
            else:
                row["sex"] = 1
                row["smoker"] = 0
            insured_info = {}
            insured_info["age"] = row["age"]
            insured_info["sex"] = row["sex"]
            insured_info["bmi"] = row["bmi"]
            insured_info["children"] = row["children"]
            insured_info["smoker"] = row["smoker"]
            insured_info["region"] = row["region"]
            insured_info["charges"] = row["charges"]
            insured_updated.append(insured_info["charges"])
            estimated_cost = 250 * float(insured_info["age"]) - 128 * float(insured_info["sex"]) + 370 * float(insured_info["bmi"]) + 425 * float(insured_info["children"]) + 24000 * float(insured_info["smoker"]) - 12500
            estimated_costs.append(estimated_cost)
        for charge in range(len(estimated_costs)):
            real_v_estimated= {"Real": insured_updated[charge], "Estimated": estimated_costs[charge]}
            real_vs_estimated.append(real_v_estimated)
        for charge in real_vs_estimated:
            x = float(charge["Real"])
            y = int(charge["Estimated"])
            difference = int(Decimal(x) - Decimal(y))
            data = {"Real": x, "Estimated": y, "Difference": difference}
            differences.append(data)
        return differences

# %%
estimated = Estimated_Insurances_Costs ()
print(estimated.estimated_difference())
# Out:
# [{'Real': 16884.924, 'Estimated': 26445, 'Difference': -9560}, {'Real': 1725.5523, 'Estimated': 4919, 'Difference': -3193}, {'Real': 4449.462, 'Estimated': 7985, 'Difference': -3535}, {'Real': 21984.47061, 'Estimated': 4150, 'Difference': 17834}, {'Real': 3866.8552, 'Estimated': 6185, 'Difference': -2318}, {'Real': 3756.6216, 'Estimated': 4645, 'Difference': -888}, {'Real': 8240.5896, 'Estimated': 11669, 'Difference': -3428}, {'Real': 7281.5056, 'Estimated': 8160, 'Difference': -878}, {'Real': 6406.4107, 'Estimated': 8637, 'Difference': -2230}, {'Real': 28923.13692, 'Estimated': 11932, 'Difference': 16991}, {'Real': 2721.3208, 'Estimated': 3451, 'Difference': -729}, {'Real': 27808.7251, 'Estimated': 36599, 'Difference': -8790}, {'Real': 1826.843, 'Estimated': 5978, 'Difference': -4151}, {'Real': 11090.7178, 'Estimated': 16105, 'Difference': -5014}, {'Real': 39611.7577, 'Estimated': 33838, 'Difference': 5773}, {'Real': 1837.237, 'Estimated': 1777, 'Difference': 60}, {'Real': 10797.3362, 'Estimated': 12185, 'Difference': -1387}, {'Real': 2395.17155, 'Estimated': 2072, 'Difference': 323}, {'Real': 10602.385, 'Estimated': 16411, 'Difference': -5808}, {'Real': 36837.467, 'Estimated': 32061, 'Difference': 4776}, {'Real': 13228.84695, 'Estimated': 15693, 'Difference': -2464}, {'Real': 4149.736, 'Estimated': 7285, 'Difference': -3135}, {'Real': 1137.011, 'Estimated': 4617, 'Difference': -3479}, {'Real': 37701.8768, 'Estimated': 32107, 'Difference': 5594}, {'Real': 6203.90175, 'Estimated': 7969, 'Difference': -1765}, {'Real': 14001.1338, 'Estimated': 13653, 'Difference': 348}, {'Real': 14451.83515, 'Estimated': 11663, 'Difference': 2788}, {'Real': 12268.63225, 'Estimated': 14098, 'Difference': -1829}, {'Real': 2775.19215, 'Estimated': 107, 'Difference': 2668}, {'Real': 38711.0, 'Estimated': 33531, 'Difference': 5180}, {'Real': 35585.576, 'Estimated': 30172, 'Difference': 5413}, {'Real': 2198.18985, 'Estimated': 1608, 'Difference': 590}, {'Real': 4687.797, 'Estimated': 4829, 'Difference': -141}, {'Real': 13770.0979, 'Estimated': 13724, 'Difference': 46}, {'Real': 51194.55914, 'Estimated': 32393, 'Difference': 18801}, {'Real': 1625.43375, 'Estimated': -192, 'Difference': 1817}, {'Real': 15612.19335, 'Estimated': 16344, 'Difference': -731}, {'Real': 2302.3, 'Estimated': 1696, 'Difference': 606}, {'Real': 39774.2763, 'Estimated': 34242, 'Difference': 5532}, {'Real': 48173.361, 'Estimated': 41263, 'Difference': 6910}, {'Real': 3046.062, 'Estimated': 3214, 'Difference': -167}, {'Real': 4949.7587, 'Estimated': 9525, 'Difference': -4575}, {'Real': 6272.4772, 'Estimated': 6233, 'Difference': 39}, {'Real': 6313.759, 'Estimated': 8868, 'Difference': -2554}, {'Real': 6079.6715, 'Estimated': 11133, 'Difference': -5053}, {'Real': 20630.28351, 'Estimated': 15051, 'Difference': 5579}, {'Real': 3393.35635, 'Estimated': 7028, 'Difference': -3634}, {'Real': 3556.9223, 'Estimated': 7236, 'Difference': -3679}, {'Real': 12629.8967, 'Estimated': 11448, 'Difference': 1181}, {'Real': 38709.176, 'Estimated': 33949, 'Difference': 4760}, {'Real': 2211.13075, 'Estimated': 5053, 'Difference': -2841}, {'Real': 3579.8287, 'Estimated': 5915, 'Difference': -2335}, {'Real': 23568.272, 'Estimated': 34285, 'Difference': -10716}, {'Real': 37742.5757, 'Estimated': 33239, 'Difference': 4503}, {'Real': 8059.6791, 'Estimated': 9262, 'Difference': -1202}, {'Real': 47496.49445, 'Estimated': 40523, 'Difference': 6973}, {'Real': 13607.36875, 'Estimated': 14497, 'Difference': -889}, {'Real': 34303.1672, 'Estimated': 28571, 'Difference': 5732}, {'Real': 23244.7902, 'Estimated': 33512, 'Difference': -10267}, {'Real': 5989.52365, 'Estimated': 10535, 'Difference': -4545}, {'Real': 8606.2174, 'Estimated': 9648, 'Difference': -1041}, {'Real': 4504.6624, 'Estimated': 7904, 'Difference': -3399}, {'Real': 30166.61817, 'Estimated': 13064, 'Difference': 17102}, {'Real': 4133.64165, 'Estimated': 4392, 'Difference': -258}, {'Real': 14711.7438, 'Estimated': 24667, 'Difference': -9955}, {'Real':  ...
